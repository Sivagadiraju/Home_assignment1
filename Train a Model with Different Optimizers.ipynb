# %% [markdown]
# <a href="https://colab.research.google.com/github/Sivagadiraju/Home_assignment1/blob/main/Train%20a%20Model%20with%20Different%20Optimizers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1.	Tensor Manipulations & Reshaping

import tensorflow as tf

# 1. Create a random tensor of shape (4, 6)
tensor = tf.random.uniform(shape=(4, 6))
print("Original Tensor:\n", tensor.numpy())

# 2. Find its rank and shape
rank = tf.rank(tensor)
shape = tf.shape(tensor)
print("\nRank of tensor:", rank.numpy())
print("Shape of tensor:", shape.numpy())

# 3. Reshape it into (2, 3, 4)
reshaped_tensor = tf.reshape(tensor, (2, 3, 4))
print("\nReshaped Tensor Shape:", reshaped_tensor.shape)

# Transpose it to (3, 2, 4)
transposed_tensor = tf.transpose(reshaped_tensor, perm=[1, 0, 2])
print("Transposed Tensor Shape:", transposed_tensor.shape)

# 4. Broadcast a smaller tensor (1, 4) to match the larger tensor
small_tensor = tf.random.uniform(shape=(1, 4))
broadcasted_tensor = tf.broadcast_to(small_tensor, shape=(4, 4))

# Add the tensors
added_tensor = tensor[:, :4] + broadcasted_tensor
print("\nBroadcasted Small Tensor:\n", broadcasted_tensor.numpy())
print("Result after Broadcasting and Addition:\n", added_tensor.numpy())
# Out:
# Original Tensor:
#  [[0.9294814  0.90773785 0.38509893 0.68397677 0.6850853  0.6777698 ]
#  [0.8606199  0.7315279  0.921088   0.57737756 0.10160732 0.83202386]
#  [0.6381999  0.78020453 0.4484346  0.01192021 0.9249551  0.3793006 ]
#  [0.40398383 0.6059836  0.15265667 0.92765296 0.6172048  0.42187464]]
#
# Rank of tensor: 2
# Shape of tensor: [4 6]
#
# Reshaped Tensor Shape: (2, 3, 4)
# Transposed Tensor Shape: (3, 2, 4)
#
# Broadcasted Small Tensor:
#  [[0.91338944 0.98341453 0.47797954 0.9300313 ]
#  [0.91338944 0.98341453 0.47797954 0.9300313 ]
#  [0.91338944 0.98341453 0.47797954 0.9300313 ]
#  [0.91338944 0.98341453 0.47797954 0.9300313 ]]
# Result after Broadcasting and Addition:
#  [[1.8428708  1.8911524  0.8630785  1.6140081 ]
#  [1.7740093  1.7149425  1.3990675  1.5074089 ]
#  [1.5515894  1.7636191  0.92641413 0.9419515 ]
#  [1.3173733  1.5893981  0.6306362  1.8576843 ]]

# %%
#2.	Loss Functions & Hyperparameter Tuning


import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# 1. Define true values (y_true) and model predictions (y_pred)
y_true = np.array([0, 1, 0])  # One-hot encoded true label
y_pred_1 = np.array([0.1, 0.8, 0.1])  # Initial prediction
y_pred_2 = np.array([0.2, 0.6, 0.2])  # Slightly modified prediction

# 2. Compute Mean Squared Error (MSE) and Categorical Cross-Entropy (CCE) losses
mse = tf.keras.losses.MeanSquaredError()
cce = tf.keras.losses.CategoricalCrossentropy()

loss_mse_1 = mse(y_true, y_pred_1).numpy()
loss_cce_1 = cce(y_true, y_pred_1).numpy()

loss_mse_2 = mse(y_true, y_pred_2).numpy()
loss_cce_2 = cce(y_true, y_pred_2).numpy()

# Print loss values
print("Loss for y_pred_1:")
print("MSE Loss:", loss_mse_1)
print("Categorical Cross-Entropy Loss:", loss_cce_1)

print("\nLoss for y_pred_2:")
print("MSE Loss:", loss_mse_2)
print("Categorical Cross-Entropy Loss:", loss_cce_2)

# 3. Plot loss function values using Matplotlib
labels = ["MSE Loss", "CCE Loss"]
loss_values_1 = [loss_mse_1, loss_cce_1]
loss_values_2 = [loss_mse_2, loss_cce_2]

x = np.arange(len(labels))  # Label positions

plt.figure(figsize=(8, 5))
plt.bar(x - 0.2, loss_values_1, width=0.4, label="y_pred_1", color="blue")
plt.bar(x + 0.2, loss_values_2, width=0.4, label="y_pred_2", color="red")

plt.xticks(x, labels)
plt.ylabel("Loss Value")
plt.title("Comparison of MSE and Cross-Entropy Loss")
plt.legend()
plt.show()
# Out:
# Loss for y_pred_1:
# MSE Loss: 0.02
# Categorical Cross-Entropy Loss: 0.22314353
#
# Loss for y_pred_2:
# MSE Loss: 0.08
# Categorical Cross-Entropy Loss: 0.5108256

# %%
#3.	Train a Model with Different Optimizers


import tensorflow as tf
import matplotlib.pyplot as plt

# 1. Load the MNIST dataset
mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalize the dataset
x_train, x_test = x_train / 255.0, x_test / 255.0

# Define a simple neural network model
def create_model():
    model = tf.keras.Sequential([
        tf.keras.layers.Flatten(input_shape=(28, 28)),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dense(10, activation='softmax')
    ])
    return model

# 2. Train two models: One with Adam and another with SGD
optimizers = {"Adam": tf.keras.optimizers.Adam(), "SGD": tf.keras.optimizers.SGD()}

history_dict = {}

for name, optimizer in optimizers.items():
    print(f"\nTraining with {name} optimizer...")

    model = create_model()
    model.compile(optimizer=optimizer,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    history = model.fit(x_train, y_train, epochs=10, validation_data=(x_test, y_test), verbose=1)
    history_dict[name] = history.history

# 3. Compare training and validation accuracy trends
plt.figure(figsize=(10, 5))

for name, history in history_dict.items():
    plt.plot(history['accuracy'], label=f"Train Accuracy - {name}")
    plt.plot(history['val_accuracy'], label=f"Val Accuracy - {name}", linestyle="dashed")

plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("Adam vs. SGD - Training & Validation Accuracy")
plt.legend()
plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
#
# Training with Adam optimizer...
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8757 - loss: 0.4309 - val_accuracy: 0.9582 - val_loss: 0.1392
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9650 - loss: 0.1217 - val_accuracy: 0.9707 - val_loss: 0.0986
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9759 - loss: 0.0801 - val_accuracy: 0.9731 - val_loss: 0.0909
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9823 - loss: 0.0602 - val_accuracy: 0.9760 - val_loss: 0.0793
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9859 - loss: 0.0450 - val_accuracy: 0.9745 - val_loss: 0.0852
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9894 - loss: 0.0346 - val_accuracy: 0.9751 - val_loss: 0.0830
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9912 - loss: 0.0291 - val_accuracy: 0.9794 - val_loss: 0.0750
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - accuracy: 0.9936 - loss: 0.0213 - val_accuracy: 0.9767 - val_loss: 0.0845
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9955 - loss: 0.0169 - val_accuracy: 0.9791 - val_loss: 0.0831
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9954 - loss: 0.0155 - val_accuracy: 0.9797 - val_loss: 0.0774
#
# Training with SGD optimizer...
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.7388 - loss: 1.0241 - val_accuracy: 0.9014 - val_loss: 0.3565
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9040 - loss: 0.3456 - val_accuracy: 0.9191 - val_loss: 0.2934
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9197 - loss: 0.2896 - val_accuracy: 0.9269 - val_loss: 0.2620
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9262 - loss: 0.2644 - val_accuracy: 0.9328 - val_loss: 0.2392
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9335 - loss: 0.2408 - val_accuracy: 0.9382 - val_loss: 0.2213
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9368 - loss: 0.2226 - val_accuracy: 0.9423 - val_loss: 0.2082
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9429 - loss: 0.2060 - val_accuracy: 0.9448 - val_loss: 0.1954
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9469 - loss: 0.1907 - val_accuracy: 0.9492 - val_loss: 0.1817
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9495 - loss: 0.1823 - val_accuracy: 0.9495 - val_loss: 0.1733
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9524 - loss: 0.1694 - val_accuracy: 0.9535 - val_loss: 0.1642
